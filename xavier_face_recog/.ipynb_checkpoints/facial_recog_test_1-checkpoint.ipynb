# %% [markdown]
# #INSTALL
#
# ```
# # Ce texte est au format code
# ```

# %%
# !git clone https://github.com/ageitgey/face_recognition.git
# Out:
# Cloning into 'face_recognition'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 942 (delta 0), reused 0 (delta 0), pack-reused 939
# Receiving objects: 100% (942/942), 101.48 MiB | 36.27 MiB/s, done.
# Resolving deltas: 100% (549/549), done.

# %%
# !apt-get install build-essential cmake
# !apt-get install libopenblas-dev liblapack-dev
# !pip3 install dlib
# !pip3 install face_recognition
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# liblapack-dev is already the newest version (3.7.1-4ubuntu1).
# libopenblas-dev is already the newest version (0.2.20+ds-4).
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.
# Requirement already satisfied: dlib in /usr/local/lib/python3.6/dist-packages (19.18.0)
# Collecting face_recognition
#   Downloading https://files.pythonhosted.org/packages/1e/95/f6c9330f54ab07bfa032bf3715c12455a381083125d8880c43cbe76bb3d0/face_recognition-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from face_recognition) (1.18.5)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.0.0)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.1.2)
# Collecting face-recognition-models>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/cf/3b/4fd8c534f6c0d1b80ce0973d01331525538045084c73c153ee6df20224cf/face_recognition_models-0.3.0.tar.gz (100.1MB)
#      |████████████████████████████████| 100.2MB 100kB/s
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=3b613e5d54e8c396aa248ddf6dc07627e1733cd79e545ac7dfd33cfc0ad205f2
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %% [markdown]
# #CREATE A DATABASE

# %%
#import cv2
#import os
#video_dir='./Desktop/Boulot/JouvencIA/video_residents'
#for root, dirs, files in os.walk(video_dir):
 #   for file in files:
  #      path=os.path.join(root,file)
   #     name=os.path.splitext(file)[0]
    #    try:
     #       os.mkdir(video_dir + '/' + name)
      #  except:
         #   print('eh mince')

# Opens the Video file
        #cap= cv2.VideoCapture(path)
        #i=0
        #while(cap.isOpened()):
         #   ret, frame = cap.read()
            #frame=cv2.rotate(frame, cv2.cv2.ROTATE_90_CLOCKWISE)
          #  if ret == False:
           #     break

            #if i%5==0:
             #   cv2.imwrite(video_dir + '/' + name + '/' + name + '_' + str(i)+'.jpg',frame)
            
            #i+=1
        
        #cap.release()
        #cv2.destroyAllWindows()

# %% [markdown]
# #SETUP

# %%
import math
import cv2
import numpy as np
from PIL import Image, ImageDraw
from IPython.display import display
import os
import os.path
import pickle
from PIL import Image, ImageDraw
import face_recognition
from face_recognition.face_recognition_cli import image_files_in_folder
import operator

ALLOWED_EXTENSIONS = {'png', 'jpg', 'jpeg'}

# %% [markdown]
# #Functions

# %%
def facetensordatabase(train_dir, verbose=False):
    """
    
    Transform a database pictures of faces into a encoding faces database.
    
    :param train_dir: path to the directory that contains a sub-directory for each known person, with its name.
    10 face pictures/ person should be good (different orientation, but not fuzzy).
     Structure for the database:
        <train_dir>/
        ├── <person1>/
        │   ├── <somename1>.jpeg
        │   ├── <somename2>.jpeg
        │   ├── ...
        ├── <person2>/
        │   ├── <somename1>.jpeg
        │   └── <somename2>.jpeg
        └── ...
        
    :param verbose: verbosity of training
    :return: returns 2 variables: * X: list of all the tensors (encoding face, shape of 128 each). lenght of X should be nbr
                                    of person in the database* nbr of faces/person 
                                    (if 10 faces/ person, lenght = 10 * nbr of person)
                                  * y: list of the name corresponding to this encoding face 
                                       (name of the folder containing the faces)
                                       lenght of y= lenght of X
                                       
    """
    X = []
    y = []

    # Loop through each person in the training set
    for class_dir in os.listdir(train_dir):
        if not os.path.isdir(os.path.join(train_dir, class_dir)):
            continue

        # Loop through each training image for the current person
        for img_path in image_files_in_folder(os.path.join(train_dir, class_dir)):
            image = face_recognition.load_image_file(img_path)
            face_bounding_boxes = face_recognition.face_locations(image)

            if len(face_bounding_boxes) != 1:
                # If there are no people (or too many people) in a training image, skip the image.
                if verbose:
                    print("Image {} not suitable for training: {}".format(img_path, "Didn't find a face" if len(face_bounding_boxes) < 1 else "Found more than one face"))
            else:
                # Add face encoding for current image to the training set
                X.append(face_recognition.face_encodings(image, known_face_locations=face_bounding_boxes)[0])
                y.append(class_dir)

    return X, y


def euclideanDistance(instance1, instance2, length):
    """
    
    Calculate a euclidean distance between 2 tensors. 
    The lenght correspond to the lenght of the tensors after encoding a face it will always be 128.
    
    :param instance1: encoding face tensor (shape 128)
    :param instance1: encoding face tensor to compare (shape 128)
    :param lenght: lenght of the tensor. Here it will be always 128 (output of face_recognition.face_encodings format)
    
    :return: returns 1 variables: A float cooresponding to the euclidean Distance between two tensors.
    
    """
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)


def getKNeighbors(X, y, image_to_test, k):
    """
    
    This function calculate the distance between an encoding face test_image and the encoding face database. 
    Then it select the k closest encoding face. 
    
    :param X: list of all the encoding face database (output of facetensordatabase() function)
    :param y: list of the name corresponding to these encoding face (output of facetensordatabase() function)
    :param image_to_test: encoding face to test against the database
    :param k: numbers of closest neighbours we want to use for the KNN
    
    :return: returns 1 variables: A list containing tuple organised as follow: (face_encoding tensor, distance, name)
    
    """
    distances = []
    length = len(image_to_test)
    for x in range(len(facedatabase)):
        dist = euclideanDistance(image_to_test, X[x], length)
        distances.append((X[x], dist, y[x]))
    distances.sort(key=operator.itemgetter(1))
    close_neighbors = []
    for x in range(k):
        close_neighbors.append((distances[x][0],distances[x][1], distances[x][2]))
    return close_neighbors


def getResponse(X, distance_threshold):
    """
    
    This function is used to classify the unknown encoding face to a corresponding member of the database when the distance is 
    close enough.
    
    :param X: output of getKNeighbors() function
    :param threshold: if the distance between the unknown encoding face and the closest neighbour is >0.6 than 
                      the unknown encoding face is classify as unknown
                      
    :return: returns 2 variables: * sorted_Vo: A list containing the name getting the majority of vote.
                                  * sorted_Vo: A list of Bol saying if the is a match or not with database
                                              True=yes
                                              False=No
    
    """
    classVotes = {}
    classVotes["Unknown Person"] = 0
    for x in range(len(X)):
        response = X[x][-1]
        thresh= X[x][-2]
        if thresh <= distance_threshold:
            if response in classVotes:
                classVotes[response] += 1
            else:
                classVotes[response] = 1
        else:
            classVotes["Unknown Person"] +=1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    are_matches = [sortedVotes[0][i] != "Unknown Person" for i in range (1)]
    sorted_Vo=[]
    sorted_Vo.append(sortedVotes[0][0])
    return sorted_Vo, are_matches

def predict(X_img_path, distance_threshold=0.6, k=3):
    """
    Recognizes faces in given image using a KNN classifier
    
    :param X_img_path: path to image to be recognized
    :param distance_threshold: (optional) distance threshold for face classification. the larger it is, the more chance
           of mis-classifying an unknown person as a known one.
    :param k: numbers of closest neighbours we want to use for the KNN
    
    
    :return: a list of names and face locations for the recognized faces in the image: [(name, bounding box), ...].
        For faces of unrecognized persons, the name 'unknown' will be returned.
        
    """
    
    if not os.path.isfile(X_img_path) or os.path.splitext(X_img_path)[1][1:] not in ALLOWED_EXTENSIONS:
        raise Exception("Invalid image path: {}".format(X_img_path))

    # Load image file and find face locations
    X_img = face_recognition.load_image_file(X_img_path)
    X_face_locations = face_recognition.face_locations(X_img)
    nbr_of_faces = len(X_face_locations)

    # If no faces are found in the image, return an empty result.
    if nbr_of_faces == 0:
        return []

    # Find encodings for faces in the test image
    faces_encodings = face_recognition.face_encodings(X_img, known_face_locations=X_face_locations)
    
    # Prepare the output image
    pil_image = Image.fromarray(X_img)
    draw = ImageDraw.Draw(pil_image)
       
    # Loop through each face found in the unknown image
    for (top, right, bottom, left), face_encoding in zip(X_face_locations, faces_encodings):
        
    # See if the face is a match for the known face(s)
        neighbors = getKNeighbors(facedatabase, Name, face_encoding, k)
        predi, are_matches = getResponse(neighbors, distance_threshold)
                 
        name = "Unknown"
        if are_matches:
            name = predi[0]

        # Draw a box around the face using the Pillow module
        draw.rectangle(((left, top), (right, bottom)), outline=(0, 0, 255))

        # Draw a label with a name below the face
        name = name.encode("UTF-8")
        text_width, text_height = draw.textsize(name)
        draw.rectangle(((left, bottom - text_height - 10), (right, bottom)), fill=(0, 0, 255), outline=(0, 0, 255))
        draw.text((left + 6, bottom - text_height - 5), name, fill=(255, 255, 255, 255))   
        
    # Remove the drawing library from memory as per the Pillow docs
    del draw

    # Display the resulting image
    return pil_image

# %% [markdown]
# #Step1: Encoding all the faces from the database

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
#  20200422_YOLO-implementation.ipynb   face_recognition	  images.txt   yolov4
#  Classroom			      facial_recog_test  'My Drive'
# 'Colab Notebooks'		      images		  YOLO

# %%
cd mydrive/
# Out:
# [Errno 2] No such file or directory: 'mydrive/'
# /content

# %%
# %ls
# Out:
# face_recognition/  gdrive/  sample_data/

# %%
Path="./facial_recog_test/train"
facedatabase, Name=facetensordatabase(train_dir=Path, verbose=True)
# Out:
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_165.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_160.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_170.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_135.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_120.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_130.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_140.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_155.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_190.jpg not suitable for training: Found more than one face
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_145.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FAVRE Reymonde/FAVRE Reymonde_150.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_45.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_125.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_55.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_10.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_260.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_60.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_75.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_115.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_70.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_105.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_110.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_100.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_65.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_255.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_265.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_240.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_95.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_80.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_165.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_175.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_160.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_170.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_215.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_5.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_15.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_180.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_155.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_20.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_190.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_25.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_150.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_30.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_145.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_235.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_185.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_195.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_35.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_220.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_245.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_85.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_130.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_90.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_120.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_135.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_40.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_250.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VAUSSENAT Odette/VAUSSENAT Odette_50.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_180.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_155.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_140.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_85.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_145.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_150.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_185.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_335.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_325.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_35.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_115.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_105.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_110.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_160.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_175.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_165.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/FOURE Claude/FOURE Claude_170.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BONNIEL Marie Louise/BONNIEL Marie Louise_280.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_240.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_135.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_280.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_45.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_185.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_145.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_150.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_90.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_230.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_50.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_225.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_190.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_85.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_140.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_95.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_195.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_40.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_235.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_220.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_55.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_210.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_205.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_65.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_70.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_165.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_170.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_160.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_75.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_200.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_60.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_105.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_110.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_215.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_310.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_305.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_265.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_270.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_300.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_125.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_290.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_285.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_260.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_115.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_275.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_100.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_315.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_25.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_250.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_130.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_30.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_295.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_120.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_35.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_245.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RUCHON Albert/RUCHON Albert_255.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_120.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_295.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_255.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_335.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_320.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_30.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_240.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_310.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_105.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_270.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_265.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_305.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_110.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_15.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_115.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_100.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_275.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_10.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_260.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_300.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_400.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_315.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_75.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_205.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_165.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_170.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_60.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_210.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_215.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_70.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_200.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_160.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_55.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_390.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_225.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_175.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_65.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_40.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_5.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_150.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_145.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_80.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_385.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_190.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_95.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_230.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_220.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_85.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_185.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_345.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_195.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_340.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_45.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_90.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_140.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_155.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_395.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_235.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_180.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_0.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_380.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_325.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_245.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_50.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_20.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_125.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_290.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_35.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_330.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_250.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_285.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_280.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_130.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_25.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/COLIN Guillaume/COLIN Guillaume_135.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_190.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_145.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_235.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_125.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_75.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_10.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_70.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_180.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_195.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_65.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_130.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_120.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_135.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_110.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_80.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_105.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_0.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_95.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_20.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_90.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_5.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_115.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_85.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_100.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_175.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_35.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_230.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_225.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_185.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_200.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_215.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_140.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RECOURAS MASSAQUANT Noelle/RECOURAS MASSAQUANT Noelle_15.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_870.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_455.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_695.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_130.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_440.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_865.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_520.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_495.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1025.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1030.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_480.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1420.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1045.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_595.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1050.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_580.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_555.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_970.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_80.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_420.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1090.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_725.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_965.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_540.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1020.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_730.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_490.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_485.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1035.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_530.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_445.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_450.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_120.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_135.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_690.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_875.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_860.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_125.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1195.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_535.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_525.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_570.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_70.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_980.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_375.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_605.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_985.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_995.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1100.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_615.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_600.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_990.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_560.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_400.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_945.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_830.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_950.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_825.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_415.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_575.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_975.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_550.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_85.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_140.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_90.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_380.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_425.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_590.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1095.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_545.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_960.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1120.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1040.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_625.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_355.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1055.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_585.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_620.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1015.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_710.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1000.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_115.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_920.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_705.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_505.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_465.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1200.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_855.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_500.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_510.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_935.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_470.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_100.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_925.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_110.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_460.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_850.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_475.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1205.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1210.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_930.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_515.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_715.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1010.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1005.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_700.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_405.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_565.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_940.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_410.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_835.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_610.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_1115.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/BUFFAT Josette/BUFFAT Josette_955.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_135.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_60.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_280.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_320.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_240.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_255.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_335.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_325.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_290.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_285.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_100.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_15.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_245.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_250.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_330.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_315.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_125.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_130.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_25.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_260.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_115.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_275.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_105.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_375.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_110.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_30.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_300.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_265.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_20.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_270.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_310.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_305.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_45.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_35.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_215.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_200.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_5.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_360.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_165.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_80.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_90.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_50.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_85.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_160.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_175.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_370.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_95.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_40.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_210.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_170.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_0.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_205.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_365.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/RIOUX Odette/RIOUX Odette_220.jpg not suitable for training: Didn't find a face
# ...
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_160.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_75.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_70.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_175.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_65.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_165.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_60.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_85.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_235.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_0.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_90.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_50.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_180.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_140.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_155.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_145.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_80.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_150.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_185.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_55.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_230.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_95.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_190.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_255.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_280.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_240.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_135.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_250.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_330.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_245.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_320.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_290.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_285.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_325.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/ARNAL Ghislaine/ARNAL Ghislaine_130.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_610.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_310.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_315.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_300.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_330.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_295.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_120.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_135.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_595.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_580.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_140.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_590.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_585.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_600.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_605.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/STEFF Roland/STEFF Roland_125.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_70.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_65.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_60.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_75.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_180.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_195.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_185.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_175.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_160.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_190.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_200.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_35.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_165.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_45.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_50.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_205.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_170.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_40.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_55.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/TULASNE Andre/TULASNE Andre_80.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VALLETTE Maria/VALLETTE Maria_100.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VALLETTE Maria/VALLETTE Maria_85.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VALLETTE Maria/VALLETTE Maria_90.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VALLETTE Maria/VALLETTE Maria_95.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/VALLETTE Maria/VALLETTE Maria_105.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/DULAC Daniele/DULAC Daniele_215.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/DULAC Daniele/DULAC Daniele_100.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/DULAC Daniele/DULAC Daniele_110.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/DULAC Daniele/DULAC Daniele_105.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_230.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_95.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_40.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_185.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_150.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_80.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_55.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_70.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_145.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_160.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_215.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_175.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_200.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_210.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_5.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_65.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_0.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_75.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_205.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_165.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_315.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_170.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_260.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_275.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_60.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_100.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_115.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_10.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_105.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_265.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_270.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_310.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_305.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_15.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_50.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_180.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_235.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_225.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_190.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_320.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_255.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_135.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_280.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_240.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_30.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_285.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_290.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_35.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_125.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_325.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_130.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_295.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_20.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_245.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_155.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_45.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_250.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_195.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_85.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_90.jpg not suitable for training: Didn't find a face
# Image ./facial_recog_test/train/PARE Simone/PARE Simone_220.jpg not suitable for training: Didn't find a face

# %% [markdown]
# Saving the encoding faces and names

# %%
with open('facedatabase', 'wb') as f:
    pickle.dump(facedatabase, f)

with open('Name','wb') as f:
    pickle.dump(Name, f)

# %% [markdown]
# Numbers of encoding faces per person

# %%
name_dictionnary={Names: len(Names) for Names in Name}
name_dictionnary
# Out:
# {'ANDELHOF Jacqueline': 19,
#  'ANTOINE Laura': 13,
#  'ARNAL Ghislaine': 15,
#  'BOLATRE Christiane': 18,
#  'BONNIEL Marie Louise': 20,
#  'BOUDILLON Jeannine': 18,
#  'BREYNAT Lucette': 15,
#  'BRISBOUT Georgette': 18,
#  'BRUN Elisabeth': 14,
#  'BUCCARANO Constance': 19,
#  'BUFFAT Josette': 14,
#  'CATALON Thérèse': 17,
#  'CLAUDINON Claudette': 19,
#  'COLIN Guillaume': 15,
#  'DE PALMA Grazia': 15,
#  'DEBARGE Yvonne': 14,
#  'DECOMMER Jocelyne': 17,
#  'DREVETON Angèle': 16,
#  'DULAC Daniele': 13,
#  'DUNAND Monique': 14,
#  'DUPRAZ Jacqueline': 17,
#  'DURET Michel': 12,
#  'FARCASSE Raymond': 16,
#  'FAVRE Reymonde': 14,
#  'FORGET Suzanne': 14,
#  'FOURE Claude': 12,
#  'GONNET Odette': 13,
#  'GOULLIART Jacqueline': 20,
#  'GUILLAUME André': 16,
#  'LACROIX Georgette': 17,
#  'LAPEYRE Jacques': 15,
#  'LECUL Andre': 11,
#  'PARE Simone': 11,
#  'PAYS Nicole': 11,
#  'PROVOST Catherine': 17,
#  'RAMAT Ida': 9,
#  'RECOURAS MASSAQUANT Noelle': 26,
#  'REYMOND Lucien': 14,
#  'RIOUX Odette': 12,
#  'ROBIN Charlette': 15,
#  'ROLLAND Simone': 14,
#  'ROUGER Geneviève': 17,
#  'ROY Claudine': 12,
#  'RUCHON Albert': 13,
#  'SANTIN Yolande': 14,
#  'SIFFLET Gilbert': 15,
#  'STEFF Roland': 12,
#  'THOMASSET Helene': 16,
#  'TRIDON christiane': 17,
#  'TULASNE Andre': 13,
#  'VALLETTE Maria': 14,
#  'VAUSSENAT Odette': 16,
#  'VOSSEY Charles': 14,
#  'ZEMLINSKI Denise': 16}

# %%
len(name_dictionnary)
# Out:
# 54

# %% [markdown]
# Loading the encoding faces and names

# %%
# %ls
# Out:
# face_recognition/  gdrive/  sample_data/

# %%
cd ../mydrive/facial_recog_test/
# Out:
# /

# %%
with open('facedatabase', 'rb') as f:
    facedatabase = pickle.load(f)

with open('Name','rb') as f:
    Name = pickle.load(f)

# %% [markdown]
# #Step2: Get a picture to test from the cam

# %%
#cam = cv2.VideoCapture('rtspsrc location=rtsp://admin:123456@192.168.1.159:554/live/ch0  latency=0 !\
#                         rtph264depay ! h264parse ! nvv4l2decoder ! nvvidconv ! video/x-raw,format=BGRx ! \
#                         videoconvert !  appsink', \
#                         cv2.CAP_GSTREAMER)
#s, im = cam.read() # captures image
#cv2.imshow("Test_Picture_moi", im) # displays captured image
#cv2.imwrite("./test_dir/test11.jpg",im) # writes image test.bmp to disk

# %% [markdown]
# #Step3: Facial recognition on the unknown picture

# %%
for image_file in os.listdir("./test"):
    full_file_path = os.path.join("./test", image_file)

    print("Looking for faces in {}".format(image_file))
    
    display(predict(full_file_path, distance_threshold=0.45, k=5))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
